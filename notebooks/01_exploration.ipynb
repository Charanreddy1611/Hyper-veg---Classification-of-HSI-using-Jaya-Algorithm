# %% [markdown]
# # HyperVeg: Data Exploration Notebook
#
# This notebook provides interactive exploration of the Indian Pines dataset and pipeline results.

# %%
import sys
sys.path.append('..')

from src.data.loader import download_indian_pines, load_indian_pines, get_class_names, get_dataset_info
from src.visualization.plots import plot_false_color_composite, plot_spectral_signatures
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load Dataset

# %%
# Download and load data
download_indian_pines()
cube, labels, wavelengths = load_indian_pines()
class_names = get_class_names()
get_dataset_info(cube, labels)

# %% [markdown]
# ## Visualizations

# %%
# False color composite
plot_false_color_composite(cube)

# %%
# Spectral signatures
plot_spectral_signatures(cube, labels, class_names)
